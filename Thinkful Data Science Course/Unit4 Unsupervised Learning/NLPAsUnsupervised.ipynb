# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test = train_test_split(emma_paras, test_size=0.4, random_state=0)

vectorizer = TfidfVectorizer(max_df=0.5, # drop words that occur in more than half the paragraphs
                             min_df=2, # only use words that appear at least twice
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )


#Applying the vectorizer
emma_paras_tfidf=vectorizer.fit_transform(emma_paras)
print("Number of features: %d" % emma_paras_tfidf.get_shape()[1])

#splitting into training and test sets
X_train_tfidf, X_test_tfidf= train_test_split(emma_paras_tfidf, test_size=0.4, random_state=0)


#Reshapes the vectorizer output into something people can read
X_train_tfidf_csr = X_train_tfidf.tocsr()

#number of paragraphs
n = X_train_tfidf_csr.shape[0]
#A list of dictionaries, one per paragraph
tfidf_bypara = [{} for _ in range(0,n)]
#List of features
terms = vectorizer.get_feature_names()
#for each paragraph, lists the feature words and their tf-idf scores
for i, j in zip(*X_train_tfidf_csr.nonzero()):
    tfidf_bypara[i][terms[j]] = X_train_tfidf_csr[i, j]

#Keep in mind that the log base 2 of 1 is 0, so a tf-idf score of 0 indicates that the word was present once in that sentence.
print('Original sentence:', X_train[5])
print('Tf_idf vector:', tfidf_bypara[5])
# Out:
# Number of features: 1948
# Original sentence: A very few minutes more , however , completed the present trial .
# Tf_idf vector: {'minutes': 0.7127450310382584, 'present': 0.701423210857947}

# %% [markdown]
# ---

# %% [markdown]
# Dimension Reduction

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer

#Our SVD data reducer.  We are going to reduce the feature space from 1379 to 130.
svd= TruncatedSVD(130)
lsa = make_pipeline(svd, Normalizer(copy=False))
# Run SVD on the training data, then project the training data.
X_train_lsa = lsa.fit_transform(X_train_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_train_lsa,index=X_train)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 45.18963084653328
# Component 0:
# " Oh !"    0.99929
# " Oh !"    0.99929
# Oh !       0.99929
# " Oh !     0.99929
# " Oh !     0.99929
# " Oh !     0.99929
# " Oh !     0.99929
# " Oh !     0.99929
# " Oh !     0.99929
# " Oh !     0.99929
# Name: 0, dtype: float64
# Component 1:
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                0.635043
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                     0.584149
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."    0.563592
# " You are right , Mrs . Weston ," said Mr . Knightley warmly , " Miss Fairfax is as capable as any of us of forming a just opinion of Mrs . Elton .                         0.556511
# " There were misunderstandings between them , Emma ; he said so expressly .                                                                                                 0.528231
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                                           0.524786
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .                                                                 0.511792
# " Now ," said Emma , when they were fairly beyond the sweep gates , " now Mr . Weston , do let me know what has happened ."                                                 0.509931
# Emma found that it was not Mr . Weston ' s fault that the number of privy councillors was not yet larger .                                                                  0.505410
# Emma could not have desired a more spirited rejection of Mr . Martin ' s prose .                                                                                            0.501436
# Name: 1, dtype: float64
# Component 2:
# CHAPTER V      0.998632
# CHAPTER V      0.998632
# CHAPTER I      0.998632
# CHAPTER X      0.998632
# CHAPTER I      0.998632
# CHAPTER X      0.998632
# CHAPTER X      0.998632
# CHAPTER I      0.998632
# CHAPTER V      0.998632
# CHAPTER XII    0.997520
# Name: 2, dtype: float64
# Component 3:
# " Ah !      0.992909
# " Ah !      0.992909
# " Ah !      0.992909
# " Ah !      0.992909
# " Ah !      0.992909
# But ah !    0.992909
# " Ah !      0.992909
# " Ah !      0.992909
# But ah !    0.992909
# " Ah !      0.992909
# Name: 3, dtype: float64
# Component 4:
# " There were misunderstandings between them , Emma ; he said so expressly .    0.650441
# " Are you well , my Emma ?"                                                    0.598948
# Emma demurred .                                                                0.598948
# Emma was silenced .                                                            0.588150
# At first it was downright dulness to Emma .                                    0.587016
# " Emma , my dear Emma "                                                        0.576658
# Emma could not resist .                                                        0.573219
# " It is not now worth a regret ," said Emma .                                  0.564913
# " For shame , Emma !                                                           0.556115
# Emma was out of hearing .                                                      0.495019
# Name: 4, dtype: float64

# %%
# Compute document similarity using LSA components
similarity = np.asarray(np.asmatrix(X_train_lsa) * np.asmatrix(X_train_lsa).T)
#Only taking the first 10 sentences
sim_matrix=pd.DataFrame(similarity,index=X_train).iloc[0:10,0:10]
#Making a plot
ax = sns.heatmap(sim_matrix,yticklabels=range(10))
plt.show()

#Generating a key for the plot.
print('Key:')
for i in range(10):
    print(i,sim_matrix.index[i])
# Out:
# Key:
# 0 That is _court_ .
# 1 " Yes , sir , I did indeed ; and I am very much obliged by your kind solicitude about me ."
# 2 " How much his business engrosses him already is very plain from the circumstance of his forgetting to inquire for the book you recommended .
# 3 To restrain him as much as might be , by her own manners , she was immediately preparing to speak with exquisite calmness and gravity of the weather and the night ; but scarcely had she begun , scarcely had they passed the sweep - gate and joined the other carriage , than she found her subject cut up  her hand seized  her attention demanded , and Mr . Elton actually making violent love to her : availing himself of the precious opportunity , declaring sentiments which must be already well known , hoping  fearing  adoring  ready to die if she refused him ; but flattering himself that his ardent attachment and unequalled love and unexampled passion could not fail of having some effect , and in short , very much resolved on being seriously accepted as soon as possible .
# 4 Emma smiled and answered " My visit was of use to the nervous part of her complaint , I hope ; but not even I can charm away a sore throat ; it is a most severe cold indeed .
# 5 A very few minutes more , however , completed the present trial .
# 6 " I am delighted to hear you speak so stoutly on the subject ," replied Emma , smiling ; " but you do not mean to deny that there was a time  and not very distant either  when you gave me reason to understand that you did care about him ?"
# 7 " Very well ; and if he had intended to give her one , he would have told her so ."
# 8 Some laughed , and answered good - humouredly .
# 9 " There appeared such a perfectly good understanding among them all " he began rather quickly , but checking himself , added , " however , it is impossible for me to say on what terms they really were  how it might all be behind the scenes .

# %% [markdown]
# ---

# %% [markdown]
# Drill 0

# %%
#Our SVD data reducer.  We are going to reduce the feature space from 1379 to 130 for the test set
svd= TruncatedSVD(130)
lsa = make_pipeline(svd, Normalizer(copy=False))
# Run SVD on the training data, then project the training data.
X_test_lsa = lsa.fit_transform(X_test_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_test_lsa,index=X_test)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:5])
# Out:
# Percent variance captured by all components: 49.354290666944564
# Component 0:
# " Oh !    0.999922
# " Oh !    0.999922
# " Oh !    0.999922
# " Oh !    0.999922
# " Oh !    0.999922
# Name: 0, dtype: float64
# Component 1:
# " Well , Mrs . Weston ," said Emma triumphantly when he left them , " what do you say now to Mr . Knightley ' s marrying Jane Fairfax ?"                                                                                                                                                                                                                                                                                                             0.612996
# After tea , Mr . and Mrs . Weston , and Mr . Elton sat down with Mr . Woodhouse to cards .                                                                                                                                                                                                                                                                                                                                                           0.601801
# Frank turned instantly to Emma , to claim her former promise ; and boasted himself an engaged man , which his father looked his most perfect approbation of  and it then appeared that Mrs . Weston was wanting _him_ to dance with Mrs . Elton himself , and that their business was to help to persuade him into it , which was done pretty soon . Mr . Weston and Mrs . Elton led the way , Mr . Frank Churchill and Miss Woodhouse followed .    0.565321
# " Mr .                                                                                                                                                                                                                                                                                                                                                                                                                                               0.519086
# While she was gone , Mr . Knightley called , and sat some time with Mr . Woodhouse and Emma , till Mr . Woodhouse , who had previously made up his mind to walk out , was persuaded by his daughter not to defer it , and was induced by the entreaties of both , though against the scruples of his own civility , to leave Mr . Knightley for that purpose .                                                                                       0.512505
# Name: 1, dtype: float64
# Component 2:
# " Ah !    0.996973
# " Ah !    0.996973
# " Ah !    0.996973
# " Ah !    0.996973
# " Ah !    0.996973
# Name: 2, dtype: float64
# Component 3:
# " Mr .                                                                                        0.633399
# After tea , Mr . and Mrs . Weston , and Mr . Elton sat down with Mr . Woodhouse to cards .    0.565840
# Mr . Knightley was thoughtful again .                                                         0.523863
# " You are not vain , Mr . Knightley .                                                         0.504791
# Mr . Weston was musing .                                                                      0.500247
# Name: 3, dtype: float64
# Component 4:
# " Yes , sometimes he can ."              0.653184
# " Yes , do ."                            0.653184
# " Yes .                                  0.653184
# " Yes I should , I am sure I should .    0.639043
# " Yes , so I imagined .                  0.614156
# Name: 4, dtype: float64

# %%
# Create a function for change in parameters for vectorized operations

def RunLSA(vectorizer):
    #Applying the vectorizer
    emma_paras_tfidf=vectorizer.fit_transform(emma_paras)
    print("Number of features: %d" % emma_paras_tfidf.get_shape()[1])

    #splitting into training and test sets
    X_train_tfidf, X_test_tfidf= train_test_split(emma_paras_tfidf, test_size=0.4, random_state=0)


    #Reshapes the vectorizer output into something people can read
    X_train_tfidf_csr = X_train_tfidf.tocsr()

    #number of paragraphs
    n = X_train_tfidf_csr.shape[0]
    #A list of dictionaries, one per paragraph
    tfidf_bypara = [{} for _ in range(0,n)]
    #List of features
    terms = vectorizer.get_feature_names()
    #for each paragraph, lists the feature words and their tf-idf scores
    for i, j in zip(*X_train_tfidf_csr.nonzero()):
        tfidf_bypara[i][terms[j]] = X_train_tfidf_csr[i, j]
    
    # Run SVD on the training data, then project the training data.
    X_train_lsa = lsa.fit_transform(X_train_tfidf)

    variance_explained=svd.explained_variance_ratio_
    total_variance = variance_explained.sum()
    print("Percent variance captured by all components:",total_variance*100)
    
    #Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
    paras_by_component=pd.DataFrame(X_train_lsa,index=X_train)
    for i in range(5):
        print('Component {}:'.format(i))
        print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])

# %%
# Change l2 to l1 penalty
vectorizer2 = TfidfVectorizer(max_df=0.5, # drop words that occur in more than half the paragraphs
                             min_df=2, # only use words that appear at least twice
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )

RunLSA(vectorizer2)
# Out:
# Number of features: 1948
# Percent variance captured by all components: 45.19491630503773
# Component 0:
# " Oh !    0.999284
# " Oh !    0.999284
# Oh !      0.999284
# " Oh !    0.999284
# " Oh !    0.999284
# " Oh !    0.999284
# " Oh !    0.999284
# " Oh !    0.999284
# " Oh !    0.999284
# " Oh !    0.999284
# Name: 0, dtype: float64
# Component 1:
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                0.634762
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                     0.572622
# " You are right , Mrs . Weston ," said Mr . Knightley warmly , " Miss Fairfax is as capable as any of us of forming a just opinion of Mrs . Elton .                         0.566052
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."    0.562398
# " There were misunderstandings between them , Emma ; he said so expressly .                                                                                                 0.528268
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                                           0.527524
# " Now ," said Emma , when they were fairly beyond the sweep gates , " now Mr . Weston , do let me know what has happened ."                                                 0.512079
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .                                                                 0.506696
# Emma found that it was not Mr . Weston ' s fault that the number of privy councillors was not yet larger .                                                                  0.506684
# " I do not admire it ," said Mr . Knightley .                                                                                                                               0.499801
# Name: 1, dtype: float64
# Component 2:
# CHAPTER X      0.998777
# CHAPTER X      0.998777
# CHAPTER V      0.998777
# CHAPTER I      0.998777
# CHAPTER I      0.998777
# CHAPTER V      0.998777
# CHAPTER V      0.998777
# CHAPTER I      0.998777
# CHAPTER X      0.998777
# CHAPTER XII    0.997789
# Name: 2, dtype: float64
# Component 3:
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# But ah !    0.992913
# Name: 3, dtype: float64
# Component 4:
# " There were misunderstandings between them , Emma ; he said so expressly .    0.650486
# Emma demurred .                                                                0.598283
# " Are you well , my Emma ?"                                                    0.598283
# Emma was silenced .                                                            0.586481
# At first it was downright dulness to Emma .                                    0.585487
# " Emma , my dear Emma "                                                        0.576690
# " It is not now worth a regret ," said Emma .                                  0.574657
# Emma could not resist .                                                        0.566140
# " For shame , Emma !                                                           0.546156
# " I am ready ," said Emma , " whenever I am wanted ."                          0.509149
# Name: 4, dtype: float64

# %%
# Toggle the max df now.
vectorizer3 = TfidfVectorizer(max_df=0.3, # drop words that occur in more than half the paragraphs
                             min_df=2, # only use words that appear at least twice
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )

RunLSA(vectorizer3)
# Out:
# Number of features: 1948
# Percent variance captured by all components: 45.208605523630375
# Component 0:
# " Oh !     0.999289
# " Oh !"    0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !"    0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# Name: 0, dtype: float64
# Component 1:
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                0.633891
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                     0.578452
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."    0.564372
# " You are right , Mrs . Weston ," said Mr . Knightley warmly , " Miss Fairfax is as capable as any of us of forming a just opinion of Mrs . Elton .                         0.558848
# " There were misunderstandings between them , Emma ; he said so expressly .                                                                                                 0.528243
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                                           0.523748
# " Now ," said Emma , when they were fairly beyond the sweep gates , " now Mr . Weston , do let me know what has happened ."                                                 0.517929
# Emma found that it was not Mr . Weston ' s fault that the number of privy councillors was not yet larger .                                                                  0.509733
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .                                                                 0.505161
# " I do not admire it ," said Mr . Knightley .                                                                                                                               0.498982
# Name: 1, dtype: float64
# Component 2:
# CHAPTER V     0.998503
# CHAPTER I     0.998503
# CHAPTER V     0.998503
# CHAPTER I     0.998503
# CHAPTER V     0.998503
# CHAPTER X     0.998503
# CHAPTER X     0.998503
# CHAPTER X     0.998503
# CHAPTER I     0.998503
# CHAPTER VI    0.997283
# Name: 2, dtype: float64
# Component 3:
# But ah !    0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !"     0.992913
# But ah !    0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# " Ah !      0.992913
# Name: 3, dtype: float64
# Component 4:
# " There were misunderstandings between them , Emma ; he said so expressly .    0.650456
# " Are you well , my Emma ?"                                                    0.598790
# Emma demurred .                                                                0.598790
# Emma was silenced .                                                            0.587512
# At first it was downright dulness to Emma .                                    0.586990
# " Emma , my dear Emma "                                                        0.576812
# Emma could not resist .                                                        0.574003
# " It is not now worth a regret ," said Emma .                                  0.561356
# " For shame , Emma !                                                           0.548265
# " I am ready ," said Emma , " whenever I am wanted ."                          0.510765
# Name: 4, dtype: float64

# %%
# Toggle the min_df next.
vectorizer4 = TfidfVectorizer(max_df=0.3, # drop words that occur in more than half the paragraphs
                             min_df=5, # only use words that appear at least 5 times
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )

RunLSA(vectorizer4)
# Out:
# Number of features: 799
# Percent variance captured by all components: 55.865767555567345
# Component 0:
# " Oh !    0.999074
# " Oh !    0.999074
# " Oh !    0.999074
# " Oh !    0.999074
# " Oh !    0.999074
# Oh !      0.999074
# " Oh !    0.999074
# " Oh !    0.999074
# " Oh !    0.999074
# " Oh !    0.999074
# Name: 0, dtype: float64
# Component 1:
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.708887
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.624811
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.616022
# " There were misunderstandings between them , Emma ; he said so expressly .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.608427
# Emma found that it was not Mr . Weston ' s fault that the number of privy councillors was not yet larger .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.581205
# Emma could not have desired a more spirited rejection of Mr . Martin ' s prose .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.580424
# " Emma ," said Mr . Knightley presently , " I have a piece of news for you .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.575477
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.557883
# Mrs . Weston was acting no part , feigning no feelings in all that she said to him in favour of the event . She had been extremely surprized , never more so , than when Emma first opened the affair to her ; but she saw in it only increase of happiness to all , and had no scruple in urging him to the utmost . She had such a regard for Mr . Knightley , as to think he deserved even her dearest Emma ; and it was in every respect so proper , suitable , and unexceptionable a connexion , and in one respect , one point of the highest importance , so peculiarly eligible , so singularly fortunate , that now it seemed as if Emma could not safely have attached herself to any other creature , and that she had herself been the stupidest of beings in not having thought of it , and wished it long ago . How very few of those men in a rank of life to address Emma would have renounced their own home for Hartfield !    0.550707
# " Now ," said Emma , when they were fairly beyond the sweep gates , " now Mr . Weston , do let me know what has happened ."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.545634
# Name: 1, dtype: float64
# Component 2:
# CHAPTER II      1.0
# CHAPTER V       1.0
# CHAPTER VIII    1.0
# CHAPTER I       1.0
# CHAPTER III     1.0
# CHAPTER III     1.0
# CHAPTER XVI     1.0
# CHAPTER VIII    1.0
# CHAPTER V       1.0
# CHAPTER I       1.0
# Name: 2, dtype: float64
# Component 3:
# " Are you well , my Emma ?"                                                    0.673952
# At first it was downright dulness to Emma .                                    0.673952
# Emma could not resist .                                                        0.673952
# Emma was silenced .                                                            0.673952
# Emma demurred .                                                                0.673952
# " For shame , Emma !                                                           0.673952
# Emma was most sincerely interested .                                           0.625281
# " Emma , my dear Emma "                                                        0.601269
# " There were misunderstandings between them , Emma ; he said so expressly .    0.567359
# Emma was out of hearing .                                                      0.564263
# Name: 3, dtype: float64
# Component 4:
# " Mr . Knightley was there too , was he ?"                                                                     0.590754
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                              0.565459
# "` Mr .                                                                                                        0.537722
# Mr . Knightley grew angry .                                                                                    0.492373
# " I do not admire it ," said Mr . Knightley .                                                                  0.490861
# " You have made her too tall , Emma ," said Mr . Knightley .                                                   0.489550
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .    0.467684
# Mr . Knightley , however , shewed no triumphant happiness .                                                    0.466206
# Mr . Knightley had done all in his power for Mr . Woodhouse ' s entertainment .                                0.461570
# While waiting for the carriage , she found Mr . Knightley by her side .                                        0.456678
# Name: 4, dtype: float64

# %%
# Increasing min_df was effective, lets increase max df and see what happens.
vectorizer5 = TfidfVectorizer(max_df=0.5, # drop words that occur in more than half the paragraphs
                             min_df=5, # only use words that appear at least 5 times
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )

RunLSA(vectorizer5)
# Out:
# Number of features: 799
# Percent variance captured by all components: 55.893307175601535
# Component 0:
# " Oh !    0.999068
# " Oh !    0.999068
# " Oh !    0.999068
# " Oh !    0.999068
# " Oh !    0.999068
# " Oh !    0.999068
# " Oh !    0.999068
# " Oh !    0.999068
# " Oh !    0.999068
# " Oh !    0.999068
# Name: 0, dtype: float64
# Component 1:
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                0.708376
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                                           0.615346
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                     0.609705
# " There were misunderstandings between them , Emma ; he said so expressly .                                                                                                 0.608433
# Emma found that it was not Mr . Weston ' s fault that the number of privy councillors was not yet larger .                                                                  0.581157
# Emma could not have desired a more spirited rejection of Mr . Martin ' s prose .                                                                                            0.571701
# " Emma ," said Mr . Knightley presently , " I have a piece of news for you .                                                                                                0.571215
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."    0.562893
# " It is not now worth a regret ," said Emma .                                                                                                                               0.553865
# " Now ," said Emma , when they were fairly beyond the sweep gates , " now Mr . Weston , do let me know what has happened ."                                                 0.552020
# Name: 1, dtype: float64
# Component 2:
# CHAPTER XVI     1.0
# CHAPTER III     1.0
# CHAPTER I       1.0
# CHAPTER X       1.0
# CHAPTER V       1.0
# CHAPTER XVII    1.0
# CHAPTER II      1.0
# CHAPTER V       1.0
# CHAPTER X       1.0
# CHAPTER XII     1.0
# Name: 2, dtype: float64
# Component 3:
# Emma could not resist .                                                        0.673875
# " Are you well , my Emma ?"                                                    0.673875
# Emma was silenced .                                                            0.673875
# " For shame , Emma !                                                           0.673875
# Emma demurred .                                                                0.673875
# At first it was downright dulness to Emma .                                    0.673875
# Emma was most sincerely interested .                                           0.627083
# " Emma , my dear Emma "                                                        0.601440
# Emma was out of hearing .                                                      0.567827
# " There were misunderstandings between them , Emma ; he said so expressly .    0.567364
# Name: 3, dtype: float64
# Component 4:
# " Mr . Knightley was there too , was he ?"                                                                     0.589857
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                              0.564839
# "` Mr .                                                                                                        0.537827
# Mr . Knightley grew angry .                                                                                    0.496564
# " I do not admire it ," said Mr . Knightley .                                                                  0.490373
# " You have made her too tall , Emma ," said Mr . Knightley .                                                   0.489198
# While waiting for the carriage , she found Mr . Knightley by her side .                                        0.470262
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .    0.467739
# Mr . Knightley , however , shewed no triumphant happiness .                                                    0.465156
# Mr . Knightley had done all in his power for Mr . Woodhouse ' s entertainment .                                0.461144
# Name: 4, dtype: float64

# %%
# Increased, but barely let's see if changing the penalization will do anything.
vectorizer6 = TfidfVectorizer(max_df=0.5, # drop words that occur in more than half the paragraphs
                             min_df=5, # only use words that appear at least 5 times
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l1', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )

RunLSA(vectorizer6)
# Out:
# Number of features: 799
# Percent variance captured by all components: 70.97373252542931
# Component 0:
# " Oh !     0.999926
# " Oh !     0.999926
# " Oh !"    0.999926
# " Oh !     0.999926
# " Oh !     0.999926
# " Oh !     0.999926
# " Oh !     0.999926
# " Oh !     0.999926
# " Oh !     0.999926
# " Oh !     0.999926
# Name: 0, dtype: float64
# Component 1:
# CHAPTER XVI     1.0
# CHAPTER II      1.0
# CHAPTER VII     1.0
# CHAPTER IV      1.0
# CHAPTER IX      1.0
# CHAPTER XIII    1.0
# CHAPTER VI      1.0
# CHAPTER VIII    1.0
# CHAPTER XVI     1.0
# CHAPTER V       1.0
# Name: 1, dtype: float64
# Component 2:
# " Ah !      0.99998
# " Ah !"     0.99998
# " Ah !      0.99998
# " Ah !      0.99998
# " Ah !      0.99998
# " Ah !      0.99998
# " Ah !      0.99998
# " Ah !      0.99998
# But ah !    0.99998
# " Ah !      0.99998
# Name: 2, dtype: float64
# Component 3:
# At first it was downright dulness to Emma .                                                                              0.890378
# Emma was silenced .                                                                                                      0.890378
# " Are you well , my Emma ?"                                                                                              0.890378
# Emma demurred .                                                                                                          0.890378
# " For shame , Emma !                                                                                                     0.890378
# Emma could not resist .                                                                                                  0.890378
# Emma remained in a state of vexation too ; but there was more indistinctness in the causes of her ' s , than in his .    0.880438
# In so large a party it was not necessary that Emma should approach her .                                                 0.872079
# Emma was out of hearing .                                                                                                0.866791
# " He knew nothing about it , Emma .                                                                                      0.864391
# Name: 3, dtype: float64
# Component 4:
# " I must not dwell upon it ," said she ." I must not think of it .                                           0.886235
# " I never should have presumed to think of it at first ," said she , " but for you .                         0.886235
# " We were too magnificent ," said he .                                                                       0.687854
# " He trifles here ," said he , " as to the temptation .                                                      0.687854
# " I see how it is ," said she .                                                                              0.687854
# " It is a most repulsive quality , indeed ," said he .                                                       0.687854
# It was kindly said , and very far from giving offence .                                                      0.673237
# " That fellow ," said he , indignantly , " thinks of nothing but shewing off his own voice .                 0.659293
# " You were speaking ," said he , gravely .                                                                   0.658558
# " If you were never particularly struck by her manners before ," said she , " I think you will to - day .    0.642575
# Name: 4, dtype: float64
