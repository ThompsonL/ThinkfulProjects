# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from six.moves import urllib
import tarfile
import os

DATASETS_URL = "https://github.com/ageron/handson-ml/raw/master/datasets"
os.chdir('C:\\Users\\liuth\\Documents\\Data')

# %%
checkbook = pd.read_csv('Checkbookdata.csv', encoding='latin1')
expsort = checkbook.loc[checkbook['Type']=='expense',['Date','Amount','Account']]
incsort = checkbook.loc[checkbook['Type']=='income',['Amount','Account']]
HOUSING_PATH = "datasets/housing"
HOUSING_URL = DATASETS_URL + "/housing/housing.tgz"

# %% [markdown]
# ---

# %% [markdown]
# Drill #1: Choosing one variable to plot and plot it 4 different ways

# %%
checkbook['Type'].value_counts().plot(kind='bar')

# %%
checkbook['Type'].value_counts().plot()

# %%
checkbook['Type'].value_counts().plot(kind='hist')

# %%
checkbook['Type'].value_counts().plot(kind='kde')

# %% [markdown]
# ---

# %% [markdown]
# Drill #2: Choose two continuous variable and plot them three different ways

# %%
sns.scatterplot(data=expsort.loc[expsort['Account']=='Chase Freedom Unlimited']\
            , x='Date' , y='Amount')

# %%
sns.boxplot(data=expsort.loc[expsort['Account']=='Chase Freedom Unlimited']\
            , x='Date' , y='Amount')

# %%
sns.swarmplot(data=expsort.loc[expsort['Account']=='Chase Freedom Unlimited']\
            , x='Date' , y='Amount')

# %% [markdown]
# ---

# %% [markdown]
# Drill #3: Choose one continuos variable and one categorical variable and plot them six different ways

# %%
sns.scatterplot(data=incsort.loc[incsort['Account']=='Chase Sapphire Reserve']\
            , x='Account' , y='Amount')

# %%
sns.boxplot(data=incsort.loc[incsort['Account']=='Chase Sapphire Reserve']\
            , x='Account' , y='Amount')

# %%
sns.barplot(data=incsort.loc[incsort['Account']=='Chase Sapphire Reserve']\
            , x='Account' , y='Amount')

# %%
sns.lineplot(data=incsort.loc[incsort['Account']=='Chase Sapphire Reserve']\
            , x='Account' , y='Amount')

# %%
sns.stripplot(data=incsort.loc[incsort['Account']=='Chase Sapphire Reserve']\
            , x='Account' , y='Amount')

# %% [markdown]
# ---

# %% [markdown]
# Challenges

# %%
def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.exists(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()
    
fetch_housing_data()

# %%
def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)
housing = load_housing_data()

# %%
sns.heatmap(housing.corr(),linewidths=0.25, square=True, cmap = "BrBG",\
            linecolor='black', annot=True)
