# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
import re
from collections import Counter
# %matplotlib inline

# %%
data = pd.read_csv('https://github.com/Thinkful-Ed/data-201-resources/raw/master/hotel-reviews.csv')

# %%
data.head(5)
# Out:
#                   address categories      city country   latitude  longitude  \
# 0  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
# 1  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
# 2  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
# 3  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
# 4  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
#
#                  name postalCode province          reviews.date  \
# 0  Hotel Russo Palace      30126       GA  2013-09-22T00:00:00Z
# 1  Hotel Russo Palace      30126       GA  2015-04-03T00:00:00Z
# 2  Hotel Russo Palace      30126       GA  2014-05-13T00:00:00Z
# 3  Hotel Russo Palace      30126       GA  2013-10-27T00:00:00Z
# 4  Hotel Russo Palace      30126       GA  2015-03-05T00:00:00Z
#
#       reviews.dateAdded  reviews.doRecommend  reviews.id  reviews.rating  \
# 0  2016-10-24T00:00:25Z                  NaN         NaN             4.0
# 1  2016-10-24T00:00:25Z                  NaN         NaN             5.0
# 2  2016-10-24T00:00:25Z                  NaN         NaN             5.0
# 3  2016-10-24T00:00:25Z                  NaN         NaN             5.0
# 4  2016-10-24T00:00:25Z                  NaN         NaN             5.0
#
#                                         reviews.text  \
# 0  Pleasant 10 min walk along the sea front to th...
# 1  Really lovely hotel. Stayed on the very top fl...
# 2  Ett mycket bra hotell. Det som drog ner betyge...
# 3  We stayed here for four nights in October. The...
# 4  We stayed here for four nights in October. The...
#
#                         reviews.title reviews.userCity reviews.username  \
# 0  Good location away from the crouds              NaN      Russ (kent)
# 1      Great hotel with Jacuzzi bath!              NaN       A Traveler
# 2                         Lugnt l��ge              NaN             Maud
# 3          Good location on the Lido.              NaN            Julie
# 4              ������ ���������������              NaN         sungchul
#
#   reviews.userProvince
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %% [markdown]
# ---

# %% [markdown]
# Cleaning Data and Pre-Processing

# %%
# Make everything lower case.
data['reviews.text'] = data['reviews.text'].str.lower()

# Remove non-text characters.
data['reviews.text'] = data['reviews.text'].str.replace(r'\.|\!|\?|\'|,|-|\(|\)', "",)

# Fill in blank reviews with '' rather than Null (which would give us errors).
data['reviews.text'] = data['reviews.text'].fillna('')

# %% [markdown]
# ---

# %% [markdown]
# Calling in specific columns .loc can actually subset more cells look at the pandas cheatsheet

# %%
data[data['hotel_country'] == 'US']
# Out:
#                 hotel_address  \
# 0      Riviera San Nicol 11/a
# 1      Riviera San Nicol 11/a
# 2      Riviera San Nicol 11/a
# 3      Riviera San Nicol 11/a
# 4      Riviera San Nicol 11/a
# 5      Riviera San Nicol 11/a
# 6      Riviera San Nicol 11/a
# 7      Riviera San Nicol 11/a
# 8      Riviera San Nicol 11/a
# 9      Riviera San Nicol 11/a
# 10     Riviera San Nicol 11/a
# 11     Riviera San Nicol 11/a
# 12     Riviera San Nicol 11/a
# 13     Riviera San Nicol 11/a
# 14     Riviera San Nicol 11/a
# 15     Riviera San Nicol 11/a
00:00:00Z  2016-06-23T16:50:58Z                  NaN
# 35909  2015-11-03T00:00:00Z  2016-06-23T16:50:58Z                  NaN
# 35910                   NaN  2015-12-01T19:40:54Z                  NaN
# 35911                   NaN  2015-12-01T19:40:54Z                  NaN
#
#        reviews.id  reviews.rating  \
# 0             NaN             4.0
# 1             NaN             5.0
# 2             NaN             5.0
# 3             NaN             5.0
# 4             NaN             5.0
# 5             NaN             5.0
# 6             NaN             4.0
# 7             NaN             4.0
# 8             NaN             3.0
# 9             NaN             4.0
# 10            NaN             4.0
# 11            NaN             3.0
# 12            NaN             4.0
# 13            NaN             4.0
# 14            NaN             4.0
# 15            NaN             4.0
# 16            NaN             4.0
# 17            NaN             4.0
# 18            NaN             4.0
# 19            NaN             1.0
# 20            NaN             1.0
# 21            NaN             5.0
# 22            NaN             4.0
# 23            NaN             5.0
# 24            NaN             5.0
# 25            NaN             5.0
# 26            NaN             4.0
# 27            NaN             4.0
# 28            NaN             4.0
# 29            NaN             4.0
# ...           ...             ...
# 35882         NaN             5.0
# 35883         NaN             5.0
# 35884         NaN             5.0
# 35885         NaN             5.0
# 35886         NaN             5.0
# 35887         NaN             5.0
# 35888         NaN             4.0
# 35889         NaN             5.0
# 35890         NaN             5.0
# 35891         NaN             5.0
# 35892         NaN             5.0
# 35893         NaN             5.0
# 35894         NaN             5.0
# 35895         NaN             5.0
# 35896         NaN             5.0
# 35897         NaN             5.0
# 35898         NaN             5.0
# 35899         NaN             5.0
# 35900         NaN             5.0
# 35901         NaN             5.0
# 35902         NaN             1.0
# 35903         NaN             5.0
# 35904         NaN             5.0
# 35905         NaN             5.0
# 35906         NaN             5.0
# 35907         NaN             5.0
# 35908         NaN             5.0
# 35909         NaN             5.0
# 35910         NaN             0.0
# 35911         NaN             0.0
#
#                                             reviews.text  \
# 0      pleasant 10 min walk along the sea front to th...
# 1      really lovely hotel stayed on the very top flo...
# 2      ett mycket bra hotell det som drog ner betyget...
# 3      we stayed here for four nights in october the ...
# 4      we stayed here for four nights in october the ...
# 5      we loved staying on the island of lido you nee...
# 6      lovely view out onto the lagoon excellent view...
# 7      ottimo soggiorno e ottima sistemazione nei gio...
# 8      gnstiger ausgangspunkt fr venedig besuche ruhi...
# 9      lidoen er perfekt til et par dages ro og afsla...
# 10     accueil chaleureux en franais changement du li...
# 11     it was ok hotel is nice from in and out but ro...
# 12     klasse frhstck freundliches und aufmerksames p...
# 13     bardzo sympatyczna obsuga klimat hotelu wietna...
# 14     bra o lugnt lge stor terrass nra till den hrli...
# 15     the hotel staff was very friendly and helpful ...
# 16     nice hotel  with very friendly staff and helpf...
# 17     wir hatten leider pech mit unserem zimmerwar i...
# 18
# 19     hotellihuone oli ullakolla jossa ei pystynyt k...
# 20     dont stay here unless youre less than 2 feet t...
# 21     we had absolutely no problems whatsoever with ...
# 22     wir buchten das hotel fr 4 nchte in der woche ...
# 23     lovely hotel 10 min walk to the water bus stop...
# 24     das hotel liegt auf der insel lido neben vened...
# 25     located on the lido i would recommend this hot...
# 26     mysigt med fina rum bra frukost och nra bde ti...
# 27     hotel ist sehr gut  wir waren zum zweiten mal ...
# 28     wir hatten ein zimmer mit balkon und blick auf...
# 29       great stayclose to ferryfood not so good nearby
# ...                                                  ...
# 35882  we stayed in smoky mountain romance with our 3...
# 35883  very nice cabin for 2 king bed loft with pool ...
# 35884  our cabin was surrounded by trees with a view ...
# 35885  beautiful luxury rental cabin development near...
# 35886  we have been using elk springs resort for seve...
# 35887  buckwild cabin is very nice only bad thing i c...
# 35888  we really enjoyed our stay the accommodations ...
# 35889  the views of the mountains was spectacular and...
# 35890  this is my first review on trip advisor simply...
# 35891  i went on a girls trip and my friend booked th...
# 35892  we had a great time loved the cabins we stayed...
# 35893  we stayed at the mount laurel cabin and it was...
# 35894  best gatlinburg cabins i cannot say enough pos...
# 35895  we recently stayed at a cabin that is managed ...
# 35896  my wife and i had the pleasure of staying at u...
# 35897  our family of 6 stayed for 6 nights and had a ...
# 35898  southern comfort cabin is great its on the end...
# 35899  we went exactly at the fall so had wonderful v...
# 35900  we took our first adult family vacation this p...
# 35901  we had a wonderful visit to breathtaking views...
# 35902  we are extremely disappointed in this company ...
# 35903  our family of 14 stayed in a 5 bedroom cabin f...
# 35904  we stayed at elk springs resort for the week o...
# 35905  we truly enjoyed staying at the elk springs re...
# 35906  we were here for a 2nd time the last weekend o...
# 35907  best of the best my family and i stayed in the...
# 35908  amazing vacation in beautiful cabin we stayed ...
# 35909  my husband and i stayed at tree tops which is ...
# 35910  to share your opinion of this businesswith yp ...
# 35911         xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#                                            reviews.title reviews.userCity  \
# 0                     Good location away from the crouds              NaN
# 1                         Great hotel with Jacuzzi bath!              NaN
# 2                                            Lugnt l��ge              NaN
# 3                             Good location on the Lido.              NaN
# 4                                 ������ ���������������              NaN
# 5                                        Very nice hotel              NaN
# 6       Lovely view out onto the lagoon. Excellent view.              NaN
# 7       Lovely view out onto the lagoon. Excellent view.              NaN
# 8                                         G��nstige Lage              NaN
# 9                                            Ro og hygge              NaN
# 10                  Tr��s bon h��tel calme et agr��able.              NaN
# 11      It was ok hotel is nice from in and out but room              NaN
# 12                               Sehr angenehmes Hotel !              NaN
# 13                                               Tip top              NaN
# 14                                       Lugnet p�� Lido              NaN
# 15                                       Lugnet p�� Lido              NaN
# 16       Nice hotel with very friendly and helpful staff              NaN
# 17                    Guter Ausgangspunkt f��r Ausfl��ge              NaN
# 18                                      ���������������.              NaN
# 19                             Hotellihuone oli pettymys              NaN
# 20                  Dungeons, Drain Flies and Centipedes              NaN
# 21            Excellent hotel with good access to Venice              NaN
# 22                           Sch��ne Lage, ruhige Gegend              NaN
# 23      Lovely stay - second time staying at this hotel.              NaN
# 24      Tolles Hotel f��r einen St��dtetrip nach Venedig              NaN
# 25            A good Hotel on the Lido - Quiet location.              NaN
# 26            A good Hotel on the Lido - Quiet location.              NaN
# 27                     Sehr sch��nes Hotel auf dem Lido.              NaN
# 28                     Sehr sch��nes Hotel auf dem Lido.              NaN
# 29                                     I would come back              NaN
# ...                                                  ...              ...
# 35882                  Best place to stay in Gatlinburg!      Goose Creek
# 35883                                      Fontana cabin        Ottoville
# 35884                                      Fontana cabin        Ottoville
# 35885                                      Fontana cabin        Ottoville
# 35886  Another great visit this year....planning to c...          Florida
# 35887  Another great visit this year....planning to c...          Florida
# 35888                   Great location, Very Clean Cabin          Florida
# 35889                           Great Views and Location     Myrtle Beach
# 35890                 Don't book with any other company!         Michigan
# 35891                   Gorgeous cabin with amazing view         Michigan
# 35892                                    GORGEOUS CABINS        Mansfield
# 35893                                        Spectacular        Mansfield
# 35894                                        Spectacular        Mansfield
# 35895                                        Spectacular        Mansfield
# 35896                                        Spectacular        Mansfield
# 35897                      Loved it! Incredible views!!!          Chicago
# 35898                      Loved it! Incredible views!!!          Chicago
# 35899                       Outstanding and Amazing view          Chicago
# 35900                       Outstanding and Amazing view          Chicago
# 35901                           Breathtaking Views Cabin        Green Bay
# 35902               Driveway is out of control dangerous        Green Bay
# 35903                     Perfect Smoky Mountain Getaway          Chicago
# 35904                     Perfect Smoky Mountain Getaway          Chicago
# 35905                                       We Loved It!        Charlotte
# 35906                        Amazing time (both times!!)        Charlotte
# 35907                        Amazing time (both times!!)        Charlotte
# 35908                        Amazing time (both times!!)        Charlotte
# 35909                        Amazing time (both times!!)        Charlotte
# 35910                                                NaN              NaN
# 35911                                                NaN              NaN
#
#            reviews.username reviews.userProvince
# 0               Russ (kent)                  NaN
# 1                A Traveler                  NaN
# 2                      Maud                  NaN
# 3                     Julie                  NaN
# 4                  sungchul                  NaN
# 5                A Traveler                  NaN
# 6                A Traveler                  NaN
# 7                A Traveler                  NaN
# 8              Doppeldecker                  NaN
# 9                A Traveler                  NaN
# 10                   Couple                  NaN
# 11                    ahsas                  NaN
# 12                    ahsas                  NaN
# 13               A Traveler                  NaN
# 14                 Elisabet                  NaN
# 15                   Mark W                  NaN
# 16              Mrs Gardner                  NaN
# 17               A Traveler                  NaN
# 18               A Traveler                  NaN
# 19               A Traveler                  NaN
# 20               A Traveler                  NaN
# 21                    Simon                  NaN
# 22               A Traveler                  NaN
# 23                   Martyn                  NaN
# 24         J��rgen + Sandra                  NaN
# 25                    A & D                  NaN
# 26                   Niklas                  NaN
# 27                   G��nni                  NaN
# 28               A Traveler                  NaN
# 29                  Armando                  NaN
# ...                     ...                  ...
# 35882             Heather B                   IN
# 35883               betty w                   OH
# 35884            Guest22169                   OH
# 35885  BG from San Jose, CA                   OH
# 35886    USTravelersFlorida                   OH
# 35887            nico ayala                   OH
# 35888                Dena F                   OH
# 35889             Djbeanman                   OH
# 35890                John P                   OH
# 35891                Berka7                   OH
# 35892              tworth20                   TX
# 35893             Chawnte F                   TX
# 35894              Julie A.                   TX
# 35895            Carolyn H.                   TX
# 35896              David F.                   TX
# 35897           MollyKMurph                   IL
# 35898                  Joel                   IL
# 35899             Vikrant S                   IL
# 35900              Diane J.                   IL
# 35901         kirstentennie                   WI
# 35902              Jeremy L                   WI
# 35903            Jennifer C                   IL
# 35904               Dean M.                   IL
# 35905       randolphtiffany                   NC
# 35906             Sabrina P                   NC
# 35907             Chelsa K.                   NC
# 35908            Heather D.                   NC
# 35909              Carol W.                   NC
# 35910        write a review                  NaN
# 35911        xxxxxxxxxxxxxx                  NaN
#
# [35912 rows x 19 columns]

# %%
data['hotel_country']
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
# 5        US
# 6        US
# 7        US
# 8        US
# 9        US
# 10       US
# 11       US
# 12       US
# 13       US
# 14       US
# 15       US
# 16       US
# 17       US
# 18       US
# 19       US
# 20       US
# 21       US
# 22       US
# 23       US
# 24       US
# 25       US
# 26       US
# 27       US
# 28       US
# 29       US
#          ..
# 35882    US
# 35883    US
# 35884    US
# 35885    US
# 35886    US
# 35887    US
# 35888    US
# 35889    US
# 35890    US
# 35891    US
# 35892    US
# 35893    US
# 35894    US
# 35895    US
# 35896    US
# 35897    US
# 35898    US
# 35899    US
# 35900    US
# 35901    US
# 35902    US
# 35903    US
# 35904    US
# 35905    US
# 35906    US
# 35907    US
# 35908    US
# 35909    US
# 35910    US
# 35911    US
# Name: hotel_country, Length: 35912, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# Vectorized Operations

# %%
# Import and initiate a vectorizer.
from sklearn.feature_extraction.text import CountVectorizer

# The max features is how many words we want to allow us to create columns for.
vectorizer = CountVectorizer(max_features=5000)

# %%
# Vectorize our reviews to transform sentences into columns.
X = vectorizer.fit_transform(data['reviews.text'])

# And then put all of that in a table.
bag_of_words = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

# %%
# Rename some columns for clarity.
data.rename(columns={'address': 'hotel_address', 'city': 'hotel_city',
                     'country':'hotel_country', 'name':'hotel_name'},
            inplace=True)

# Join our bag of words back to our initial hotel data.
full_df = data.join(bag_of_words)

# %%
# X is our words.
X = bag_of_words

# Y is our hotel name (the outcome we care about).
Y_hotel = data['hotel_name']

# %%
# Import a random forest model.
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# Fit that random forest model to our data. (.fit transforms the model to a training model)
rfc.fit(X,Y_hotel)
# Out:
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ---

# %% [markdown]
# Running Tests

# %%
# Write your own dream vacation review here...
test_review = ['''
    I loved the beach and the sunshine and the clean and modern room.
    ''']

# %%
# Convert your test review into a vector.
X_test = vectorizer.transform(test_review).toarray()

# %%
# Match your review.
prediction = rfc.predict(X_test)[0]

# %%
# Return the essential information about your match.
data[data['hotel_name'] == prediction][['hotel_name', 'hotel_address', 
                                        'hotel_city', 'hotel_country']].head(1)
# Out:
#                                  hotel_name hotel_address  hotel_city  \
# 4744  The Alexandrian, Autograph Collection   480 King St  Alexandria
#
#      hotel_country
# 4744            US

# %%
data[data['hotel_name'] == 'Super 8 Kansas City Airport']
# Out:
#              hotel_address categories   hotel_city hotel_country   latitude  \
# 25988  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25989  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25990  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25991  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25992  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25993  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25994  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25995  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25996  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25997  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25998  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 25999  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26000  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26001  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26002  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26003  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26004  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26005  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26006  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26007  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26008  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26009  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26010  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26011  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26012  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26013  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26014  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26015  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26016  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26017  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# ...                    ...        ...          ...           ...        ...
# 26029  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26030  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26031  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26032  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26033  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26034  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26035  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26036  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26037  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26038  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26039  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26040  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26041  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26042  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26043  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26044  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26045  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26046  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26047  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26048  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26049  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26050  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26051  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26052  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26053  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26054  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26055  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26056  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26057  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
# 26058  11900 N W Plaza Cir     Hotels  Kansas City            US  39.309014
#
#        longitude                   hotel_name postalCode province  \
# 25988   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25989   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25990   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25991   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25992   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25993   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25994   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25995   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25996   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25997   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25998   -94.6826  Super 8 Kansas City Airport      64153       MO
# 25999   -94.6826  Super 8 Kansas City Airport      64153       MO
# 
# 26015         NaN             2.0
# 26016         NaN             3.0
# 26017         NaN             4.0
# ...           ...             ...
# 26029         NaN             3.0
# 26030         NaN             4.0
# 26031         NaN             3.0
# 26032         NaN             1.0
# 26033         NaN             1.0
# 26034         NaN             1.0
# 26035         NaN             2.0
# 26036         NaN             2.0
# 26037         NaN             5.0
# 26038         NaN             1.0
# 26039         NaN             1.0
# 26040         NaN             3.0
# 26041         NaN             2.0
# 26042         NaN             1.0
# 26043         NaN             1.0
# 26044         NaN             2.0
# 26045         NaN             1.0
# 26046         NaN             4.0
# 26047         NaN             1.0
# 26048         NaN             5.0
# 26049         NaN             4.0
# 26050         NaN             3.0
# 26051         NaN             1.0
# 26052         NaN             5.0
# 26053         NaN             3.0
# 26054         NaN             1.0
# 26055         NaN             1.0
# 26056         NaN             3.0
# 26057         NaN             4.0
# 26058         NaN             3.0
#
#                                             reviews.text  \
# 25988  i was very unhappy when we got there when i bo...
# 25989  it was ok for a one night stay prior to flying...
# 25990  great spot near airport food was a 5 minute dr...
# 25991  the door in our room was very ajare very loose...
# 25992  when we arrived the hotel clerk rushed us thro...
# 25993  horrible experience none of the online picture...
# 25994  accused of vandalizing the room despite not kn...
# 25995  clean convenient to airport helpful front desk...
# 25996                                      nice location
# 25997  bath tub was dirty and towels were old and sta...
# 25998  this was the worse hotel i have ever been in t...
# 25999  i booked my room two days in advancehotel mana...
# 26000             nice excellent location to the airport
# 26001  this is a hotel that ive stayed in before and ...
# 26002  no heat in room they brought a portable heater...
# 26003  i always try to see the good in what ever may ...
# 26004  the hotel was quit run down 5 night stay and t...
# 26005                            dirty and decrepit room
# 26006  the staff was nice and there had been remodeli...
# 26007  dirty towels and sheets with stains leaking ce...
# 26008  old facility needs updated poor quality pillow...
# 26009  i thought it was a decent hotel they were unde...
# 26010  cannot expect a lot from a super 8 motel when ...
# 26011  wasnt the best but definitely not the worst th...
# 26012  hotel under heavy renovation but staff is doin...
# 26013  there were about 5 bugs in the room and a gian...
# 26014              there was no shampoo for the bathroom
# 26015  under construction had to turn off room heater...
# 26016  hotel is undergoing renovation so will be grea...
# 26017  very accommodating close to airport it had a r...
# ...                                                  ...
# 26029  they are remodeling and should be great when c...
# 26030  it was clean it was busy we were not there ver...
# 26031                                         great stay
# 26032  room smells of mildew ceiling was patched with...
# 26033  food left in fridge from previous ppl moldy in...
# 26034  the hotel is open during a major renovation wh...
# 26035  they never came and fixed the tv so we could w...
# 26036  staff was rude and didnt speak english very we...
# 26037  as an airport hotel its hard to beat it was qu...
# 26038  the hotel room smelled bad the bedding was dir...
# 26039  there were only about 20 of the rooms occupied...
# 26040  when checked into the room there was water in ...
# 26041  clean i didnt see any bugs or other health iss...
# 26042                 worst night sleep ever never again
# 26043                                    it had beg bugs
# 26044  the pictures of the rooms are nothing like wha...
# 26045  breakfast was horrible old apple juice and ora...
# 26046  recommendation great will stay again if needed...
# 26047  this was a good place for last minute its acco...
# 26048  as a smoker i always feel like a 2nd class cit...
# 26049                              the wifi did not work
# 26050  for a last minute booking due to an early flig...
# 26051  they put us in a room above the check in area ...
# 26052  overall great the parking lot was a little snu...
# 26053  we were told that the parking was free when we...
# 26054     was not i mean was not absolutely happy at all
# 26055  the door did not lock the rooms smelled like s...
# 26056  my reserved room was not ready when i checked ...
# 26057  very pleased great value beds were comfy a/c c...
# 26058  on a business trip quick service simple clean ...
#
#                                            reviews.title reviews.userCity  \
# 25988                                                NaN              NaN
# 25989                                  Convenient to MCI              NaN
# 25990     Great place to rest your head on your travels.              NaN
# 25991                                  just for the nite              NaN
# 25992                                 Not a clean option              NaN
# 25993  Hotel a war zone, unclean, spiders & gunfire o...              NaN
# 25994                              Accused of vandalizim              NaN
# 25995                        Convenient and clean hotel.              NaN
# 25996                                     Super Great #8              NaN
# 25997                                     Super Great #8              NaN
# 25998                                     Terrible Hotel              NaN
# 25999                                     Terrible Hotel              NaN
# 26000             Great for a place for an airport stay.              NaN
# 26001             Great for a place for an airport stay.              NaN
# 26002                                    No heat in room              NaN
# 26003                                   Under Remodeling              NaN
# 26004                                       Dissapointed              NaN
# 26005                                       Dissapointed              NaN
# 26006                                           Not bad.              NaN
# 26007                                           Terrible              NaN
# 26008                                           Terrible              NaN
# 26009                                           Terrible              NaN
# 26010                      Budget price and budget stay.              NaN
# 26011          Just for an overnight stay. Nothing more.              NaN
# 26012                    Nice large rooms king non-smoke              NaN
# 26013                               Good except for bugs              NaN
# 26014                               Good except for bugs              NaN
# 26015                               Good except for bugs              NaN
# 26016                                      Will be great              NaN
# 26017                        Nice hotel close to airport              NaN
# ...                                                  ...              ...
# 26029                 Great location and shuttle aervice              NaN
# 26030                               Overall decent place              NaN
# 26031                               Overall decent place              NaN
# 26032   Was in convenient location for why we were there              NaN
# 26033                                        Thumbs down              NaN
# 26034                               Construction Central              NaN
# 26035                           Pay the extra for better              NaN
# 26036                                          Just okay              NaN
# 26037       very convenient to the airport, good shuttle              NaN
# 26038       very convenient to the airport, good shuttle              NaN
# 26039                                 Under Construction              NaN
# 26040         Easy access, basic breakfast with waffles.              NaN
# 26041                        Clean. Got what I paid for.              NaN
# 26042                                              Dirty              NaN
# 26043                                           Bed bugs              NaN
# 26044                        Nothing like th"se pictures              NaN
# 26045       sucky experience the worse ever! ! ! ! ! ! !              NaN
# 26046                                              Great              NaN
# 26047                                Nice abs convenient              NaN
# 26048                            Very nice for a smoker.              NaN
# 26049                            Very nice for a smoker.              NaN
# 26050                              Comfortable and clean              NaN
# 26051          Go somewhere else this place is a joke!!!              NaN
# 26052                                     not bad at all              NaN
# 26053                            Convenient and friendly              NaN
# 26054                            Convenient and friendly              NaN
# 26055                                       Do not stay.              NaN
# 26056                          You get what you pay for.              NaN
# 26057                                        Great Value              NaN
# 26058                                     Simple, clean.              NaN
#
#       reviews.username reviews.userProvince
# 25988             Edie                  NaN
# 25989             Edie                  NaN
# 25990            James                  NaN
# 25991       A Traveler                  NaN
# 25992             Dawn                  NaN
# 25993       A Traveler                  NaN
# 25994            Pader                  NaN
# 25995       A Traveler                  NaN
# 25996       A Traveler                  NaN
# 25997       A Traveler                  NaN
# 25998              kim                  NaN
# 25999       A Traveler                  NaN
# 26000       A Traveler                  NaN
# 26001       A Traveler                  NaN
# 26002       A Traveler                  NaN
# 26003            Billy                  NaN
# 26004              Kim                  NaN
# 26005       A Traveler                  NaN
# 26006       A Traveler                  NaN
# 26007       A Traveler                  NaN
# 26008       A Traveler                  NaN
# 26009       A Traveler                  NaN
# 26010             Hugh                  NaN
# 26011     Not Provided                  NaN
# 26012             Mark                  NaN
# 26013       A Traveler                  NaN
# 26014           Robert                  NaN
# 26015       A Traveler                  NaN
# 26016          Richard                  NaN
# 26017          Richard                  NaN
# ...                ...                  ...
# 26029          Richard                  NaN
# 26030           Daniel                  NaN
# 26031            james                  NaN
# 26032            james                  NaN
# 26033           Brenda                  NaN
# 26034       A Traveler                  NaN
# 26035       A Traveler                  NaN
# 26036            Chris                  NaN
# 26037             Bill                  NaN
# 26038       A Traveler                  NaN
# 26039             Mark                  NaN
# 26040           Yvonne                  NaN
# 26041       A Traveler                  NaN
# 26042       A Traveler                  NaN
# 26043       A Traveler                  NaN
# 26044       A Traveler                  NaN
# 26045       A Traveler                  NaN
# 26046       A Traveler                  NaN
# 26047                m                  NaN
# 26048                m                  NaN
# 26049       A Traveler                  NaN
# 26050       A Traveler                  NaN
# 26051            Jacob                  NaN
# 26052       A Traveler                  NaN
# 26053       A Traveler                  NaN
# 26054          Anthony                  NaN
# 26055            Aimee                  NaN
# 26056       A Traveler                  NaN
# 26057          Coranne                  NaN
# 26058       A Traveler                  NaN
#
# [71 rows x 19 columns]

# %% [markdown]
# ---

# %% [markdown]
# The decision tree model process

# %%
rfc.decision_path(X)
# Out:
# (<35912x390488 sparse matrix of type '<class 'numpy.int64'>'
#  	with 88991200 stored elements in Compressed Sparse Row format>,
#  array([     0,  39461,  78722, 117877, 156456, 195663, 234634, 273237,
#         312184, 351307, 390488], dtype=int32))

# %%
rfc.estimators_
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1849704594, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1853809871, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=2000179347, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1466738703, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=850660624, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1356430462, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=345944729, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1783960625, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1833590677, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1891860668, splitter='best')]

# %%
estimator = rfc.estimators_[8]

from sklearn.tree import export_graphviz
# Export as dot file
export_graphviz(estimator, out_file='tree.dot', 
                feature_names = vectorizer.get_feature_names(),
                class_names = Y_hotel,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'tree.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-a3a280c59c39> in <module>
#       7                 class_names = Y_hotel,
#       8                 rounded = True, proportion = False,
# ----> 9                 precision = 2, filled = True)
#      10
#      11 # Convert to png using system command (requires Graphviz)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     457
#     458         # Now recurse the tree and add node & edge attributes
# --> 459         recurse(decision_tree.tree_, 0, criterion=decision_tree.criterion)
#     460
#     461         # If required, draw leaf nodes at same depth as each other
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
# --> 381                         depth=depth + 1)
#     382
#     383         else:
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     377             if left_child != _tree.TREE_LEAF:
#     378                 recurse(tree, left_child, criterion=criterion, parent=node_id,
# --> 379                         depth=depth + 1)
#     380                 recurse(tree, right_child, criterion=criterion, parent=node_id,
#     381                         depth=depth + 1)
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     334             out_file.write('%d [label=%s'
#     335                            % (node_id,
# --> 336                               node_to_str(tree, node_id, criterion)))
#     337
#     338             if filled:
#
# C:\Users\liuth\WPy-3670\python-3.6.7.amd64\lib\site-packages\sklearn\tree\export.py in node_to_str(tree, node_id, criterion)
#     277             # Classification
#     278             value_text = np.around(value, precision)
# --> 279         elif np.all(np.equal(np.mod(value, 1), 0)):
#     280             # Classification without floating-point weights
#     281             value_text = value.astype(int)
#
# KeyboardInterrupt:
